# %%
a=5
b=10.5
c='venki'
d=5
e=complex(a,b)
print(e.real)
if (a==d):
  print("true")
elif(a<b):
  print("b is greater than a")
else:
  print("false")
# Out:
# 5.0
# true

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
for i in range (1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
while i < 6:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
class grandfather:
  def __init__(self,a,b):
    self.a=a
    self.b=b
p1 = grandfather("sai",21)
print(p1.a)
print(p1.b)
# Out:
# sai
# 21

# %%
#list
list =[1,2,3,4,5,6]
list
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
print(len(list))
# Out:
# 6

# %%
print(list[2])
# Out:
# 3

# %%
print(list[0:6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(list[2:3])
# Out:
# [3]

# %%
print(list[-2])
# Out:
# 5

# %%
print(list[-4:-1])
# Out:
# [3, 4, 5]

# %%
tuple=(1,2,3,4,5,6)
print(tuple[1:5])
# Out:
# (2, 3, 4, 5)

# %%
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
set={1,2,3,4}
print(type(set))
# Out:
# <class 'set'>

# %%
set1={2,5,6}
c = set.union(set1)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6}
