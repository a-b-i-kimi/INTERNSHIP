# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,4,6,8,10])
y=np.array([10,20,30,40,50])
plt.plot(x,y)
plt.title("Line Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(True)

# %%
import seaborn as sns
x=np.array([2,4,6,8,10])
y=np.array([10,20,30,40,50])
sns.scatterplot
# Out:
# <Axes: >
